# %% [markdown]
# **[Implement analytics solutions using Microsoft Fabric](https://learn.microsoft.com/en-us/training/courses/dp-600t00/)**

# %% [markdown]
# # **[Prepare AI-ready analytics data in Microsoft Fabric](https://learn.microsoft.com/training/paths/prepare-ai-ready-analytics-data/)**

# %% [markdown]
# ## **Prepare semantic models for AI in Power BI and Microsoft Fabric**

# %% [markdown]
# ### **Introduction**

# %% [markdown]
# #### Why AI Needs Business Context
# Humans understand business meaning naturally.
#
# Example:
# > Which product is most profitable?
#
# A business user may understand whether "profitable" means:
#
# ✅ Total Profit
#
# or
#
# ✅ Profit Margin
#
# based on organizational context.
#
# AI does **not** automatically understand this context.
# #### The Challenge
# Consider two measures:
# ```dax
# Profit =
# [Revenue] - [Cost]
# ```
# and
# ```dax
# Profit Margin =
# DIVIDE([Profit],[Revenue])
# ```
# If a user asks:
# > Which product is most profitable?
#
# Copilot must determine which measure to use.
#
# Without clear business definitions:
#
# ❌ Wrong measure selection \
# ❌ Ambiguous answers \
# ❌ Reduced AI trust
# #### Why Semantic Models Matter for AI
# For traditional BI:
# > User → Report Author → Semantic Model
#
# The report author chooses:
#
# ✅ Correct measures \
# ✅ Correct filters \
# ✅ Correct visuals
#
# For AI:
# > User → Copilot → Semantic Model
#
# The semantic model must provide the context directly.
# #### Goal of AI-Ready Semantic Models
# Make business meaning explicit.
#
# The semantic model should clearly communicate:
#
# ✅ Business concepts \
# ✅ Relationships \
# ✅ Measures \
# ✅ Definitions \
# ✅ Data meaning
# #### What AI Needs
# ##### 1. Clear Measures
# Good:
# * Total Revenue
# * Profit Margin %
# * Customer Lifetime Value
#
# Bad:
# * Measure1
# * Calc_7
# * Rev_Final_V2
# ##### 2. Clear Relationships
# Good:
# * Customer
# * Product
# * Sales
# * Date
#
# with proper star-schema relationships.
#
# Bad:
# * Table1
# * Table2
# * Multiple ambiguous relationships
# ##### 3. Clear Business Definitions
# Example:
# ```
# Revenue = Total Sales before Returns
# ```
# Document the meaning.
# ##### 4. Trusted Data
# AI performs best when using:
#
# ✅ Centralized \
# ✅ Validated \
# ✅ Governed
#
# semantic models.
# #### Reduce Ambiguity
# A key AI design principle.
# ##### Ambiguous Model
# Contains:
# * Profit
# * Margin
# * ProfitCalc
# * Revenue2
#
# with no descriptions.
#
# Result:
#
# ❌ Copilot may select wrong measures.
# ##### Well-Prepared Model
# Contains:
# * Total Profit
# * Profit Margin %
# * Revenue Before Returns
#
# with descriptions.
#
# Result:
#
# ✅ Better AI answers. \
# ✅ More reliable outputs.
# #### AI Uses the Semantic Model
# Copilot and Fabric AI rely on:
#
# ✅ Metadata \
# ✅ Measure names \
# ✅ Relationships \
# ✅ Model descriptions \
# ✅ Business definitions
# ##### Therefore
# A well-designed semantic model benefits both:
# * Humans
# * AI
# #### AI-Ready Design Principles
# ##### Descriptive Names
# Use:
# * Revenue
# * Profit Margin
# * Customer Count
#
# instead of technical names.
# ##### Consistent Definitions
# One measure:
# * Revenue
#
# should have one meaning everywhere.
# ##### Shared Semantic Models
# Provide:
#
# ✅ Single Source of Truth \
# ✅ Consistent AI results \
# ✅ Governance
# ##### Star Schema
# Helps AI understand:
# > Customer → Sales → Product
#
# relationships correctly.
# #### Fabric IQ and Semantic Models
# Semantic models provide:
#
# ✅ Structured business knowledge \
# ✅ Metrics \
# ✅ Relationships \
# ✅ Definitions
#
# Fabric IQ can add value by helping:
#
# ✅ Interpret questions \
# ✅ Generate insights \
# ✅ Resolve business meaning
#
# but it still depends heavily on a well-prepared semantic model.
# #### Exam Focus
# This module teaches how to:
#
# ✅ Prepare semantic models for AI \
# ✅ Reduce ambiguity \
# ✅ Improve Copilot responses \
# ✅ Improve Fabric IQ results \
# ✅ Add business context to data
# #### Key Statement to Remember
# > Preparing semantic models for AI reduces the need for Copilot to choose between ambiguous measures, technical fields, or competing definitions.
#
# This is one of the most important concepts in the module.
# #### Exam Quick Facts
# ✅ AI relies on semantic models for business context \
# ✅ Ambiguous measures can lead to incorrect AI answers \
# ✅ Clear measure names improve AI accuracy \
# ✅ Shared semantic models provide trusted definitions \
# ✅ Star schemas improve AI understanding \
# ✅ AI uses:
# * Measures
# * Relationships
# * Metadata
# * Descriptions
#
# ✅ The goal is to make business meaning explicit \
# ✅ Better-prepared semantic models produce more reliable Copilot and Fabric IQ responses
# #### Memory Trick
# ##### AI Readiness Formula
# > Clear Measures + Clear Relationships + Business Definitions + Trusted Semantic Model → Reliable Copilot Answers
#
# ##### Most Tested Concept ⭐
# AI does not automatically know business meaning. The semantic model must provide the context needed to interpret business questions correctly.

# %% [markdown]
# ### **Explain how semantic model context guides Copilot answers**

# %% [markdown]
# ![copilot-schema-reduction-flow.png](attachment:copilot-schema-reduction-flow.png)
#
# #### Key Idea
# **Copilot does not understand your business automatically.**
#
# It relies on the **semantic model** to understand:
#
# ✅ Measures \
# ✅ Relationships \
# ✅ Field names \
# ✅ Descriptions \
# ✅ Data types \
# ✅ Synonyms
#
# If the semantic model is unclear, Copilot must guess.
# #### Example Problem
# User asks:
# > Which products are most profitable?
#
# Semantic model contains:
# * Profit
# * Profit Margin
# ##### Question
# Which measure should Copilot use?
# > Profit? or Profit Margin?
#
# If the semantic model provides no context:
#
# ❌ Copilot may choose the wrong measure. \
# ❌ Business decisions may be affected.
# #### What Copilot Reads
# When a user asks a question, Copilot reads metadata from the semantic model.
#
# It uses:
# ##### Measure Names
# Examples:
# * Profit
# * Revenue
# * Gross Margin
# ##### Descriptions
# Examples:
# * Profit = Revenue minus Cost
# * Profit Margin = Profit as a percentage of Revenue
# ##### Relationships
# Examples:
# * Product → Sales
# * Customer → Sales
# * Date → Sales
# ##### Data Types
# Examples:
# * Currency
# * Percentage
# * Date
# ##### Synonyms
# Examples:
# * Revenue
# * Sales
# * Income
#
# can be related.
# #### Schema Reduction
# A critical exam concept.
# ##### What is Schema Reduction?
# Copilot narrows the semantic model down to only the objects relevant to the question.
# ##### Example
# Question:
# > Which products are most profitable?
#
# Instead of scanning:
# * Customer
# * Vendor
# * Region
# * Employee
# * Inventory
#
# Copilot focuses on:
# * Product
# * Profit
# * Profit Margin
# * Sales
#
# This filtering process is called **Schema Reduction**
# #### Why Ambiguity Happens
# Suppose:
# * Profit
# * Profit Margin
# * Gross Profit
# * Net Profit
#
# exist in the model.
#
# Without descriptions Copilot has insufficient context.
#
# Result:
#
# ❌ Ambiguous interpretation \
# ❌ Wrong measure selection \
# ❌ Inconsistent answers
# #### Semantic Model = Business Context
# The semantic model is where Copilot gets business meaning.
#
# Think:
# > User Question → Copilot → Semantic Model → Business Context → Answer
#
# ##### Exam Statement
# If business meaning is not in the semantic model, Copilot has to guess.
# #### Why Fix the Semantic Model First?
# You could create AI instructions such as:
# * Always use Profit.
# * Never use Profit Margin.
#
# But that only helps:
# * Copilot
#
# Reports still remain ambiguous.
# #### Better Approach
# Fix the semantic model itself.
# ##### Example:
# * Total Profit
# ##### Description:
# * Revenue minus Cost.
# * Profit Margin %
# ##### Description:
# * Profit divided by Revenue.
# ##### Now:
# ✅ Reports use correct definitions \
# ✅ Copilot uses correct definitions \
# ✅ Future AI tools use correct definitions
# #### Principle
# ##### Fix the Source Once
# Instead of:
# * Patch Every Consumer
#
# Fix:
# * Semantic Model
#
# once.
# ##### Exam Tip
# Semantic model design comes before AI-specific guidance.
# #### AI Preparation Hierarchy
# > Semantic Model → Copilot Instructions → AI Experiences
#
# Strong semantic models reduce the need for AI instructions.
# #### Business Requirements Come First
# Before testing Copilot:
#
# Define:
# ##### Business Questions
# Example:
# * Which products are most profitable?
# ##### Correct Measure
# Example:
# * Profit
#
# NOT
# * Profit Margin
# ##### Required Fields
# Example:
# * Product
# * Revenue
# * Profit
# #### Using Requirements to Diagnose Problems
# Suppose requirements say:
# * **Question**: "Most profitable product"
# * **Expected Measure**: Profit
# * **Copilot returns**: Profit Margin
# ##### Diagnosis:
# ✅ Measure metadata problem \
# ✅ Ambiguity in semantic model
#
# The requirements tell you exactly where to look.
# #### What Makes a Semantic Model AI-Ready?
# ##### Clear Measure Names
# Good:
# * Total Profit
# * Profit Margin %
# * Revenue Before Returns
#
# Bad:
# * Measure1
# * Calc7
# * Profit_New
# ##### Clear Descriptions
# Example:
# * Total Profit:
# * Revenue minus cost.
# ##### Proper Relationships
# Example:
# > Product → Sales → Date
#
# ##### Consistent Definitions
# One concept:
# * One Meaning
#
# across reports and AI.
# #### Impact on Copilot
# ##### Poor Semantic Model
# > Ambiguous Fields → Copilot Guesses → Inconsistent Answers
#
# ##### Good Semantic Model
# > Clear Definitions → Correct Schema Reduction → Reliable Answers
#
# #### Exam Quick Facts
# ✅ Copilot reads:
# * Names
# * Descriptions
# * Measures
# * Relationships
# * Data Types
# * Synonyms
#
# ✅ Schema Reduction = narrowing the model to relevant fields \
# ✅ Semantic model provides business context \
# ✅ Ambiguous measures cause Copilot confusion \
# ✅ Fix semantic model issues before adding AI instructions \
# ✅ Shared semantic models create consistent AI behavior \
# ✅ Business requirements define the expected answer \
# ✅ Clear naming and descriptions improve Copilot accuracy
# #### Memory Trick
# ##### Copilot Decision Flow
# > Question → Schema Reduction → Semantic Model Context → Measure Selection → Answer
#
# ##### Most Tested Concept ⭐
# The semantic model is where Copilot gets its business context. If the meaning isn't clearly defined there, Copilot must guess.

# %% [markdown]
# ### **Design a focused gold layer for AI consumption**

# %% [markdown]
# ![gold-layer-star-schema.png](attachment:gold-layer-star-schema.png)
#
# #### What is the Gold Layer?
# The **Gold Layer** is the business-ready semantic layer that AI tools like Copilot should use.
#
# Its purpose is to provide:
#
# ✅ Trusted measures \
# ✅ Clear business entities \
# ✅ Simple relationships \
# ✅ Business-friendly names \
# ✅ Minimal ambiguity
#
# Think of it as:
# > Raw Data (Bronze) → Cleaned Data (Silver) → Business Semantic Model (Gold) → Copilot / Reports
#
# #### Goal of the Gold Layer
# Provide:
# ##### One Clear Path
# From **Business Question** to **Correct Data**
# ##### Example
# Question:
# > Sales by City
#
# Copilot should automatically find:
# > Total Sales → Customer → Customer City
#
# Not:
# * Store City
# * Customer Key
# * Old Sales Measure
# #### Business Entities
# ##### What Are Business Entities?
# Real business concepts.
#
# Examples:
# * Customer
# * Product
# * Date
# * Store
# * Sales
# ##### Good Design
# * *Customer* describes *Who buys products*
# * *Product* describes *What is sold*
# * *Date* describes *When sales occur*
# * *Sales* describes *Business transactions*
# #### Why Entities Matter
# Copilot follows relationships between entities.
#
# Example:
# > Sales → Customer → Customer City
#
# This provides the context needed for:
# * Sales by City
# #### Use Business Names
# A key AI design principle.
# ##### Good
# * Customer
# * Product
# * Sales
# * Revenue
# ##### Bad
# * `dim_customer_v2`
# * `tbl_sales_final`
# * `fact_orders_2025`
# ##### Why?
# Good names describe:
# * Business Meaning
#
# Bad names describe:
# * Technical Implementation
# ##### Exam Rule
# Use business-friendly names.
# #### Distinguish Similar Concepts
# Copilot may see multiple similar fields.
# ##### Example
# * Customer City
# * Store City
# ##### Question:
# * Sales by City
#
# Which city should Copilot choose?
#
# Without context:
#
# ❌ It may guess incorrectly.
# #### Use Descriptions
# Descriptions help Copilot choose correctly.
# ##### Customer City
# Description:
# * City where the customer resides.
# ##### Store City
# Description:
# * City where the store is located.
# #####
# Result:
#
# ✅ Copilot understands the difference.
# #### Description Guidelines
# ##### Table Descriptions
# Answer:
# > What does each row represent?
#
# Example:
# > Customer. Each row represents a unique customer.
#
# ##### Column Descriptions
# Answer:
# > What does this value mean?
#
# Example:
# > Customer City. City where the customer resides.
#
# ##### Measure Descriptions
# Answer:
# > How is this calculated?
#
# Example:
# > Total Sales. Sum of completed sales transactions excluding returns.
#
# #### Important Copilot Limitation
# Copilot reads only first 200 Characters of descriptions.
# ##### Exam Tip
# Put the most important information first.
# #### Visible vs Hidden Fields
# Visible fields influence what Copilot can use.
# ##### Keep Visible
# Only:
#
# ✅ Trusted measures \
# ✅ Business attributes \
# ✅ Business entities
#
# **Example**
#
# Visible:
# * Total Sales
# * Customer City
# * Product Category
# ##### Hide Technical Fields
# Examples:
# ```
# CustomerKey
# ProductKey
# LoadDate
# AuditColumn
# OldMeasure
# ```
# **Why?**
#
# Technical fields create:
#
# ❌ Noise \
# ❌ Ambiguity \
# ❌ Wrong AI choices
# ##### Exam Rule
# Hide fields humans and AI should not use.
# #### Synonyms
# ##### Purpose
# Help Copilot understand business vocabulary.
# ##### Example
# * **Measure**: Total Sales
# * **Users ask**: Revenue
# * **Add synonym**: Revenue
# * **for**: Total Sales
# ##### Result
# ✅ Copilot matches the question correctly.
# #### Important Synonym Rule
# Use synonyms for:
# * Different Words
#
# Not for:
# * Poor Semantic Design
# ##### Good
# Revenue → Total Sales
# ##### Bad
# Using synonyms to compensate for:
# * Measure1
# * Field2
# * Calc7
# #### Testing the Gold Layer
# Always validate using real business questions.
# ##### Example Question
# Sales by City
# ##### Expected Path:
# > Total Sales → Customer → Customer City
#
# If Copilot chooses:
# > Store City or `CustomerKey`
#
# there is ambiguity in the model.
# #### Gold Layer Checklist
# ##### Business Entities
# ✅ Customer \
# ✅ Product \
# ✅ Date \
# ✅ Sales
# ##### Naming
# ✅ Business-friendly names \
# ❌ Technical names
# ##### Descriptions
# ✅ Tables \
# ✅ Columns \
# ✅ Measures
# ##### Visibility
# ✅ Keep business fields visible \
# ✅ Hide technical fields
# ##### Synonyms
# ✅ Alternative business terms
# ##### Testing
# ✅ Trace business questions through the model
# #### Example AI-Ready Model
# > Customer → Customer City
#
# > Product → Product Category
#
# > Sales → Total Sales
#
# Question:
# > Show sales by city.
#
# Copilot can easily identify:
# * **Measure**: Total Sales
# * **Entity**: Customer
# * **Attribute**: Customer City
# #### Exam Quick Facts
# ✅ Gold Layer = Business-ready semantic layer \
# ✅ Goal: One clear path from question to answer \
# ✅ Use business entity names:
# * Customer
# * Product
# * Sales
# * Date
#
# ✅ Avoid technical names:
# * `dim_customer_v2`
# * `tbl_sales_final`
#
# ✅ Descriptions help Copilot distinguish similar concepts \
# ✅ Table descriptions explain entities \
# ✅ Column descriptions explain values \
# ✅ Measure descriptions explain calculations \
# ✅ Copilot reads only the first 200 characters of descriptions \
# ✅ Hide technical fields like:
# * Keys
# * Load metadata
# * Deprecated fields
#
# ✅ Synonyms help map business vocabulary \
# ✅ Test semantic models using real business questions
# #### Memory Trick
# ##### Gold Layer Formula
# > Clear Entities + Clear Names + Clear Descriptions + Hidden Technical Fields → Reliable Copilot Answers
#
# ##### Most Tested Concept ⭐
# The Gold Layer should provide Copilot with one clear business path from a question to the correct measure, relationship, and attribute.

# %% [markdown]
# ### **Select the appropriate prep for AI control**

# %% [markdown]
# ![prep-for-ai-decision-flow.png](attachment:prep-for-ai-decision-flow.png)
#
# #### Key Idea
# Before marking a semantic model **Approved for Copilot**, identify whether Copilot still has AI-specific problems that the semantic model alone cannot solve.
#
# Power BI's Prep data for AI feature provides **3 controls**, each designed for a different problem.
# #### Prep Data for AI Controls
# There are three controls:
# 1. AI Data Schema
# 2. AI Instruction
# 3. Verified Answer
# #### 1. AI Data Schema
# ##### Purpose
# Limits which fields Copilot can use.
#
# Think:
# > Too Much Data → AI Data Schema → Focused AI Dataset
#
# ##### When to Use
# Use when:
#
# ✅ Semantic model contains many subject areas \
# ✅ Copilot only needs a subset \
# ✅ You want to reduce distractions
# ##### Example
# Semantic model contains:
# * Sales
# * Finance
# * HR
# * Service
# * Inventory
#
# But Copilot should answer **Sales Questions Only**
#
# Create an AI Data Schema containing:
# * Total Sales
# * Customer
# * Product
# * Date
# * Customer City
# ##### Benefit
# * Copilot ignores unrelated fields.
# * Less ambiguity.
# * More accurate answers.
# ##### Exam Memory
# **Problem**
# > Too Many Fields
#
# **Solution**
# > ✅ AI Data Schema
#
# #### 2. AI Instruction
# ##### Purpose
# Add business rules that the semantic model cannot express.
# ##### Example
# Business rule:
# > When users say "city", assume Customer City unless Store City is mentioned.
#
# * This isn't a relationship problem.
# * This isn't a naming problem.
# * It's a **Business Rule**
# ##### Solution
# Use:
# > ✅ AI Instruction
#
# ##### When to Use
# Use when:
#
# ✅ Business interpretation is needed \
# ✅ Context isn't fully represented in the model \
# ✅ Copilot needs extra guidance
# ##### Example
# `Profit = Total Profit` not Profit Margin
#
# for specific types of questions.
# ##### Exam Memory
# **Problem**
# > Copilot Needs Guidance
#
# **Solution**
# > ✅ AI Instruction
#
# #### 3. Verified Answer
# ##### Purpose
# Return a predefined, human-approved answer.
# ##### Example
# Executives frequently ask:
# > Show current sales performance by region.
#
# You always want:
#
# ✅ Same visual \
# ✅ Same filters \
# ✅ Same format
# ##### Solution
# Create a:
# > ✅ Verified Answer
#
# ##### What Happens?
# > **Question matches**: Trigger Phrase → **Power BI returns**: Approved Visual
#
# instead of generating a new answer.
# ##### When to Use
# Use when:
#
# ✅ Same question occurs repeatedly \
# ✅ One approved answer should always appear \
# ✅ Consistency is critical
# ##### Examples
# * Sales by Region
# * Executive KPI Dashboard
# * Current Revenue Map
# ##### Exam Memory
# **Problem**
# > * Need Same Approved Answer
# > * Every Time
#
# **Solution**
# > ✅ Verified Answer
#
# #### Choosing the Correct Control
# | Problem                    | Control         |
# | -------------------------- | --------------- |
# | Too many fields            | AI Data Schema  |
# | Need business rule         | AI Instruction  |
# | Need approved fixed answer | Verified Answer |
#
# #### Example Scenarios
# ##### Scenario 1
# Copilot sees:
# * Sales
# * Finance
# * Inventory
# * HR
#
# and becomes confused.
#
# **Use**
# > ✅ AI Data Schema
#
# ##### Scenario 2
# Users say:
# > City
#
# but should mean:
# > Customer City
#
# **Use**
# > ✅ AI Instruction
#
# ##### Scenario 3
# Executives always want the same approved revenue dashboard.
#
# **Use**
# > ✅ Verified Answer
#
# #### Testing Prep for AI Controls
# Very important exam topic.
#
# Do NOT approve immediately.
# #### Testing Process
# ##### Step 1
# Gather business questions.
#
# Examples:
# * Sales by City
# * Top Products
# * Most Profitable Region
# ##### Step 2
# Ask Copilot those questions.
# ##### Step 3
# Verify:
# * **AI Data Schema**
# > Did Copilot only use approved fields?
#
# * **AI Instructions**
# > Did Copilot follow the business rule?
#
# * **Verified Answers**
# > Did the approved visual appear?
#
# #### Negative Testing
# Also test:
# * Questions Similar
# * To Trigger Phrases
# ##### Example
# Verified Answer Trigger:
# * Sales by Region
#
# Test:
# * Sales trends by region
# ##### Verify:
# ✅ Trigger only activates when intended.
# #### Troubleshooting
# If results are wrong:
# > Identify the cause.
#
# ##### Ask:
# **Is it the Semantic Model?**
#
# Examples:
# * Wrong Measure
# * Poor Description
# * Bad Relationship
#
# **Is it AI Data Schema?**
#
# Too many or too few fields?
#
# **Is it AI Instruction?**
#
# Missing business rule?
#
# **Is it Verified Answer?**
#
# Incorrect trigger phrase?
# #### Important Testing Rule
# Change:
#
# ✅ One Thing At A Time
#
# Then:
#
# ✅ Reopen Copilot \
# ✅ Retest
#
# This makes it easier to identify the source of the issue.
# #### Approval Concept
# Once testing succeeds:
#
# Mark semantic model:
#
# ✅ Approved for Copilot
# ##### Important Exam Concept
# Approval means:
# > The tested business questions work reliably.
#
# It does NOT mean:
# > Copilot answers every possible future question perfectly.
#
# #### Approval Checklist
# Before Approval:
#
# ✅ Semantic model has clear entities \
# ✅ Measures are defined \
# ✅ Descriptions exist \
# ✅ AI schema is focused \
# ✅ AI instructions are correct \
# ✅ Verified answers work \
# ✅ Priority business questions pass testing
# #### Decision Tree
# ##### Problem
# > Too Many Fields? → AI Data Schema
#
# > Need Business Guidance? → AI Instruction
#
# > Need Same Approved Answer? → Verified Answer
#
# #### Exam Quick Facts
# ✅ Prep data for AI contains three controls:
# * AI Data Schema
# * AI Instruction
# * Verified Answer
#
# ✅ AI Data Schema limits fields available to Copilot \
# ✅ AI Instruction adds business rules \
# ✅ Verified Answer returns a predefined approved response \
# ✅ Use AI Data Schema when Copilot sees too much data \
# ✅ Use AI Instruction when Copilot needs contextual guidance \
# ✅ Use Verified Answer when a question should always return a fixed answer \
# ✅ Test all controls before approval \
# ✅ Retest after every change \
# ✅ Approval means trusted behavior for tested questions
# #### Memory Trick
# ##### AI Controls Formula
# > Too Much Data → AI Data Schema
#
# > Need Guidance → AI Instruction
#
# > Need Fixed Answer → Verified Answer
#
# ##### ⭐ Most tested concept:
# Choose the control based on the problem:
# * AI Data Schema → Focus the data
# * AI Instruction → Guide the reasoning
# * Verified Answer → Fix the response

# %% [markdown]
# ### **Decide when to extend a semantic model with Fabric IQ**

# %% [markdown]
# ![ontology-boundary.png](attachment:ontology-boundary.png)
#
# #### Key Idea
# A well-designed semantic model helps Copilot answer questions correctly within a team.
#
# But different teams may define the same business concepts differently.
#
# Example:
# * Sales Team → Customer includes resellers
# * Service Team → Customer includes direct buyers only
#
# Result:
#
# ❌ Different answers \
# ❌ Inconsistent AI experiences \
# ❌ Confusion across departments
# #### What Fabric IQ Adds
# Fabric IQ introduces:
# ##### Ontologies
# An ontology provides:
#
# ✅ Shared business definitions \
# ✅ Shared business relationships \
# ✅ Enterprise-wide consistency \
# ✅ AI understanding across multiple models
# #### Semantic Model vs Ontology
# ##### Semantic Model
# Contains:
#
# ✅ Measures \
# ✅ Calculations \
# ✅ Relationships \
# ✅ Filters \
# ✅ Report-specific logic
# ##### Example
# * Total Sales
# * Profit Margin
# * YTD Revenue
#
# remain inside the semantic model.
# ##### Ontology
# Contains:
#
# ✅ Business meaning \
# ✅ Shared entity definitions \
# ✅ Shared relationship definitions
# ##### Example
# * Customer
# * Product
# * Sales
# * Store
# * Employee
#
# defined consistently for everyone.
# #### Why Ontologies Matter
# Without an ontology:
# > Team A's Customer ≠ Team B's Customer
#
# A data agent querying both models may not know:
# > Which definition is correct.
#
# With an ontology:
# > Customer
#
# has one approved definition.
# ##### Result:
# ✅ Consistent Copilot responses \
# ✅ Consistent Fabric IQ responses \
# ✅ Consistent enterprise vocabulary
# #### What an Ontology Defines
# ##### Entity Definitions
# Example:
# > Customer
#
# means:
# > Person or organization that purchases products.
#
# ##### Relationships
# Example:
# > Customer → Purchases → Product
#
# ##### Properties
# Example:
# * Customer Name
# * Customer Region
# * Customer Segment
# #### When to Create an Ontology
# A common exam topic.
#
# You should create an ontology when BOTH conditions are true.
# ##### Condition 1
# Definition is:
#
# ✅ Stable
#
# Example:
# * Customer
# * Product
# * Order
#
# have agreed meanings.
#
# If definitions change often:
#
# ❌ Not ontology-ready.
# ##### Condition 2
# Other teams need it.
#
# Example:
# * Customer
#
# used by:
#
# ✅ Sales \
# ✅ Marketing \
# ✅ Service \
# ✅ Finance
#
# Then it belongs in the ontology.
# #### Ontology Decision Rule
# > Stable Definition + Multiple Teams Need It → Ontology Candidate
#
# #### What Stays in the Semantic Model?
# Not everything belongs in an ontology.
# ##### Examples
# * Report Filters
# * Custom Measures
# * Calculated Columns
# * Page Logic
#
# remain in:
#
# ✅ Semantic Model
# ##### Why?
# * They are report-specific.
# * Not enterprise concepts.
# #### What Belongs in an Ontology?
# Examples:
# * Customer
# * Product
# * Store
# * Supplier
# * Region
# ##### Why?
# Shared business meaning across teams.
# #### When NOT to Create an Ontology
# Avoid ontology publication when:
#
# ❌ Definition is still evolving \
# ❌ Ownership is unclear \
# ❌ Only one team uses the concept
# ##### Exam Rule
# Publish only:
#
# ✅ Stable entities \
# ✅ Clearly owned entities
# #### Ontology Generation
# Fabric IQ can generate an ontology automatically.
# #### Generation Mapping
# | Semantic Model | Ontology           |
# | -------------- | ------------------ |
# | Tables         | Entity Types       |
# | Columns        | Properties         |
# | Relationships  | Relationship Types |
#
# ##### Example
# * **Semantic Model**: Customer Table **becomes**: Customer Entity
# * **Column**: Customer City **becomes**: Customer Property
# * **Relationship**: Customer → Sales **becomes**: Ontology Relationship
# #### Important Exam Tip
# Generated ontology is:
# > Starting Point
#
# not final design.
#
# Still review:
#
# ✅ Names \
# ✅ Keys \
# ✅ Entity definitions \
# ✅ Relationship directions
#
# before enterprise use.
# #### Direct Lake Requirement
# Another potential exam area.
#
# If the ontology needs to answer questions directly from bound data:
#
# Requirements include:
#
# ✅ Direct Lake storage mode \
# ✅ Inbound public access enabled on the backing lakehouse workspace
# #### Storage Mode Behavior
# ##### Direct Lake
# Supports:
#
# ✅ Definitions \
# ✅ Data bindings
# ##### Import
# Supports:
#
# ✅ Definitions \
# ❌ Data bindings
# ##### DirectQuery
# Supports:
#
# ✅ Definitions \
# ❌ Data bindings
# ##### Exam Memory
# > Direct Lake → Definitions + Data Bindings
#
# #### Semantic Model + Fabric IQ
# Think of them as complementary.
# ##### Semantic Model
# Provides:
#
# ✅ Measures \
# ✅ Business calculations \
# ✅ Security \
# ✅ Reporting logic
# ##### Fabric IQ Ontology
# Provides:
#
# ✅ Shared business language \
# ✅ Enterprise definitions \
# ✅ Cross-model consistency \
# ✅ AI alignment
# #### Example
# ##### Semantic Model
# * Total Revenue
# * Profit Margin
# ##### Ontology
# * Customer
# * Product
# * Region
#
# Together:
#
# ✅ Better AI understanding \
# ✅ Consistent Copilot answers \
# ✅ Reusable enterprise knowledge
# #### Decision Framework
# Ask:
# ##### Is it a business entity?
# If no:
#
# → Keep in semantic model
# ##### Is it stable?
# If no:
#
# → Don't publish
# ##### Is it shared by other teams?
# If no:
#
# → Keep local
# ##### Stable + Shared?
# If yes:
#
# → Add to ontology
# #### Exam Quick Facts
# ✅ Fabric IQ uses ontologies \
# ✅ Ontologies standardize business definitions \
# ✅ Semantic models still contain:
# * Measures
# * Calculations
# * Filters
#
# ✅ Create ontologies only when:
# * Definitions are stable
# * Multiple teams need them
#
# ✅ Tables become entity types \
# ✅ Columns become properties \
# ✅ Relationships become relationship types \
# ✅ Fabric IQ can generate ontologies automatically \
# ✅ Always review generated ontologies before publishing \
# ✅ Direct Lake supports ontology data bindings \
# ✅ Import and DirectQuery support definitions only
# #### Memory Trick
# ##### Ontology Rule
# > Stable + Shared → Ontology
#
# ##### Semantic Model vs Fabric IQ
# > Semantic Model → Calculations
#
# > Fabric IQ → Business Meaning
#
# ##### ⭐ Most Tested Concept:
# Use Fabric IQ when a business entity has a stable definition that multiple teams need to share consistently across semantic models and AI experiences.

# %% [markdown]
# ### **Validate AI readiness**

# %% [markdown]
# #### What is AI Readiness?
# AI readiness means:
#
# ✅ Copilot consistently chooses the correct measures \
# ✅ Copilot uses the correct dimensions \
# ✅ Copilot follows business rules \
# ✅ Copilot returns expected visuals \
# ✅ Copilot follows the intended reasoning path
# #### Key Exam Concept
# AI readiness is about validating the reasoning path, not just the final answer.
#
# A correct number can still come from:
#
# ❌ The wrong measure \
# ❌ The wrong field \
# ❌ The wrong relationship \
# ❌ The wrong business logic
# #### Example
# Question:
# > Which product is most profitable?
#
# Expected:
# > Profit Margin
#
# Copilot uses:
# > Total Profit
#
# The answer might accidentally look correct today.
#
# But when data changes:
#
# ❌ Results become unreliable.
# #### Why Testing Matters
# Without testing:
# > Semantic Model → Copilot → Untested Answers
#
# With testing:
# > Business Question → Validate Reasoning Path → Approve
#
# #### Testing Process
# ##### Step 1
# Identify priority business questions.
#
# Examples:
# * Which category has the highest sales?
# * Which product is most profitable?
# * How do sales compare by city?
# ##### Step 2
# Document expected behavior.
#
# Before asking Copilot:
#
# Write down:
#
# ✅ Correct measure \
# ✅ Correct dimension \
# ✅ Correct filters \
# ✅ Expected business logic
# #### Example Test Cases
# | Business Question            | Expected Logic                                |
# | ---------------------------- | --------------------------------------------- |
# | Highest total sales category | Total Sales + Product Category                |
# | Most profitable product      | Profit Margin (unless total profit requested) |
# | Sales by city                | Customer City, not technical fields           |
#
# ##### Exam Tip
# Always define expected behavior BEFORE testing.
# #### Test Multiple Variations
# Copilot may answer differently depending on wording.
#
# Example:
# * Which category has highest sales?
# * Top-selling category?
# * Best performing product category by revenue?
#
# All should use:
# > Total Sales
#
# ##### Exam Rule
# * One correct answer is not enough.
# * Test multiple phrasings.
# #### Diagnose Wrong Answers
# ##### Use
# > How Copilot arrived at this
#
# This shows:
#
# ✅ Measures selected \
# ✅ Fields selected \
# ✅ Filters applied \
# ✅ Reasoning path
# #### Alternative Inspection
# Use:
# > Add to Page
#
# Inspect:
#
# ✅ Fields \
# ✅ Measures \
# ✅ Visual structure
#
# directly.
# ##### Benefit
# Confirms exactly what Copilot used.
# #### Find the Earliest Error
# Identify where the reasoning became incorrect.
#
# Example:
# > Question → Wrong Measure → Wrong Result
#
# Fix the measure selection problem first.
# #### Troubleshooting Matrix
# ##### Problem 1
# Wrong measure or entity used.
# ##### Fix
# Improve:
#
# ✅ Names \
# ✅ Descriptions \
# ✅ Relationships
# ##### Example
# **Profit** vs **Profit Margin**
#
# Better descriptions reduce ambiguity.
# ##### Problem 2
# Technical field appears.
# ##### Fix
# Remove it from:
#
# ✅ AI Data Schema
# ##### Example:
# `CustomerKey`
#
# should not appear in Copilot answers.
# ##### Problem 3
# Unknown business term.
# ##### Fix
# Add:
#
# ✅ Synonym
# ##### Example:
# **Revenue** as a synonym for **Total Sales**
# ##### Problem 4
# Missing business rule.
# ##### Fix
# Add:
#
# ✅ AI Instruction
# ##### Example:
# City means Customer City
#
# unless Store City is requested.
# ##### Problem 5
# Question should always return one approved result.
# ##### Fix
# Create:
#
# ✅ Verified Answer
# #### Retesting
# After every change:
# ##### Step 1
# Apply fix.
# ##### Step 2
# Close Copilot pane.
# ##### Step 3
# Reopen Copilot pane.
# ##### Step 4
# Ask the same question again.
# ##### Why?
# Confirms:
#
# ✅ Fix works \
# ✅ No new issues introduced
# #### Approval Criteria
# Approve only when:
#
# ✅ Priority questions consistently produce correct answers \
# ✅ Trusted measures are used \
# ✅ Correct relationships are used \
# ✅ Correct filters are applied \
# ✅ Business rules are followed
# #### Important Exam Concept
# Approval means:
#
# Trusted Responses for Tested Questions
#
# Approval does NOT mean:
#
# Copilot can answer every possible question perfectly.
# #### Maintain a Regression Set
# ##### Save
# ✅ Failed prompts \
# ✅ Fixes applied \
# ✅ Successful tests
# ##### Purpose
# Retest after:
#
# ✅ New measures \
# ✅ New dimensions \
# ✅ New AI instructions \
# ✅ Semantic model changes
#
# This creates a **Regression Test Suite**
# #### AI Readiness Is Continuous
# Not:
# > One-Time Checklist
#
# Instead:
# > Release Practice
#
# Every model change may require:
#
# ✅ Retesting \
# ✅ Verification \
# ✅ Approval review
# #### Validation Workflow
# > Business Questions → Expected Measures → Test Copilot → Inspect Reasoning Path → Fix Issues → Retest → Approve
#
# #### Complete AI Readiness Checklist
# ##### Semantic Model
# ✅ Clear entities \
# ✅ Clear measures \
# ✅ Descriptions completed \
# ✅ Relationships validated
# ##### Gold Layer
# ✅ Technical fields hidden \
# ✅ Business fields visible \
# ✅ Synonyms configured
# ##### Prep for AI
# ✅ AI Data Schema tested \
# ✅ AI Instructions tested \
# ✅ Verified Answers tested
# ##### Validation
# ✅ Multiple question variations tested \
# ✅ Reasoning path verified \
# ✅ Regression prompts saved
# #### Exam Quick Facts
# ✅ AI readiness validates reasoning, not just outputs \
# ✅ Define expected measures before testing \
# ✅ Test multiple versions of each question \
# ✅ Use "How Copilot arrived at this" to inspect reasoning \
# ✅ Use "Add to page" to inspect generated visuals \
# ✅ Wrong measure/entity:
# * Improve names
# * Improve descriptions
# * Improve relationships
#
# ✅ Technical field:
# * Remove from AI Data Schema
#
# ✅ Unknown business phrase:
# * Add a synonym
#
# ✅ Missing business rule:
# * Add AI Instruction
#
# ✅ Fixed approved answer:
# * Create Verified Answer
#
# ✅ Retest after every change \
# ✅ Approval applies only to tested scenarios \
# ✅ AI readiness is an ongoing process
# #### Memory Trick
# ##### AI Validation Formula
# > Question → Expected Logic → Copilot Test → Reasoning Review → Fix → Retest
#
# ##### Troubleshooting Shortcut ⭐
# > Wrong Field? → AI Data Schema
#
# > Wrong Meaning? → AI Instruction
#
# > Wrong Term? → Synonym
#
# > Wrong Measure? → Metadata
#
# > Need Fixed Result? → Verified Answer
#
# ##### Most Tested Concept
# Approve a semantic model only when priority business questions consistently use the correct reasoning path, not merely when the returned number appears correct.

# %% [markdown]
# ### **Exercise: Prepare a semantic model for AI**

# %% [markdown]
# #### Set up the environment
# > Note: You need a paid Fabric capacity to complete this exercise. A Fabric trial doesn’t support Copilot capabilities. For information about Fabric licenses, see Microsoft Fabric licenses.
#
# You need Power BI Desktop (November 2025 or newer) installed to complete this exercise. Note: UI elements may vary slightly depending on your version.
# 1. On the Fabric home page, select **Power BI**.
# 2. In the left navigation bar, select **Workspaces**, and then select **New workspace**.
# 3. Name the new workspace, such as `dp_fabric`, select a licensing mode that includes Fabric capacity (paid F2 or higher), and select **Apply**.
# 4. Open a web browser and enter the following URL to download the [30-prepare-model-ai zip folder](https://github.com/MicrosoftLearning/mslearn-fabric/raw/refs/heads/main/Allfiles/Labs/30/30-prepare-model-ai.zip)
# 5. Save the file in **Downloads** and extract the zip file to the **30-prepare-model-ai** folder.
# 6. Open the **30-Starter-Sales Analysis.pbix** file from the folder you extracted.
# > Ignore and close any warnings asking to apply changes. Don’t select Discard changes.
#
# 7. On the **Home** ribbon, select the **Copilot** button. When prompted to select a workspace, choose the workspace you created (for example, `dp_fabric`) and select **Connect**. This links Power BI Desktop to your Fabric capacity for Copilot features.
# 8. On the **Home** ribbon, locate the **Prep data for AI** button. If you don’t see it, confirm that you have a current version of Power BI Desktop.
# > Note: Prep for AI is a preview feature. If the tabs in the Prep for AI dialog appear disabled, navigate to Modeling > Q&A setup and enable Q&A for the model. Close the dialog and try again.
#
# > Tip: If you are in a lab VM and have any problems entering the text, you can download the [30-snippets.txt](https://github.com/MicrosoftLearning/mslearn-fabric/raw/refs/heads/main/Allfiles/Labs/30/30-snippets.txt), saving it on the VM. The file contains all the text snippets and trigger phrases used in this lab.
#
# #### Simplify the data schema
# Hiding technical fields helps Copilot focus on business-relevant data and produce more accurate responses. In this section, you use the Prep for AI dialog to deselect surrogate keys, sort columns, and ETL metadata from the AI data schema.
# 1. On the **Home** ribbon, select **Prep data for AI**.
# 2. In the dialog that opens, select **Simplify the data schema** from the left navigation or by selecting the card.
# 3. Expand each table and deselect fields that aren’t relevant for business users. By default, all fields are visible to AI. For each table, **only keep the following fields**:
#     * **Customer**: `City`, `CustomerName`
#     * **Date**: `Date`, `Day`, `Month`, `Year`
#     * **Product**: `Category`, `ListPrice`, `ProductName`, `StandardCost`, `Subcategory`
#     * **Sales**: `LineTotal`, `OrderDate`, `OrderQty`, `Profit`, `Profit Margin`, `SalesOrderID`, `Total Sales`, `TotalCost`, `UnitPrice`
# 4. Select **Apply**.
#
#     Deselected fields include surrogate keys (`CustomerKey`, `ProductKey`), sort helper columns (`Day (Sort Order)`, `Month (Sort Order)`), ETL metadata (`LoadDate`, `SourceSystem`), and internal identifiers (`SalesOrderLineNumber`). Deselecting `LoadDate` also removes its auto-generated Date Hierarchy, which is expected — the dedicated `Date` table handles time-based analysis.
# #### Add AI instructions
# Table names and field descriptions don’t always capture your organization’s business rules and terminology. In this section, you write AI instructions that provide Copilot with business context, including key terminology, analysis preferences, and data scope.
# 1. In the Prep for AI dialog, select **Add AI instructions** from the left navigation.
# 2. In the instructions text box, enter the following business context:
#
# ```
# This model contains retail sales data for an outdoor recreation products company.
#
# Key business terminology:
# - "Revenue" and "sales" refer to the Total Sales measure.
# - Products are organized by Category and Subcategory.
#
# Analysis guidance:
# - When users ask about "top products," rank by Total Sales descending.
# - When users ask about profitability, use the Profit Margin measure (percentage), not the Profit measure (absolute amount).
# - Customers are identified by CustomerName, not CustomerKey.
#
# Data scope: This model covers retail sales from January 2024 through December 2025.
# ```
# 3. Select **Apply** and then **Close** to return to the **Report** view.
# #### Create verified answers
# Predefined responses ensure that common business questions always return the same accurate visual. In this section, you create verified answers for two report visuals and assign trigger phrases that map to frequently asked questions.
# 1. From the **Sales Overview** report page, select the card visual that shows `Total Sales`.
# 2. Select the **…** menu on the visual, then select **Set verified answer**.
# 3. In the verified answer dialog, add the following trigger phrases:
#     * `What were total sales?`
#     * `Show me total revenue`
#     * `How much did we sell?`
# 4. Select **Apply**.
# 5. Select the bar chart visual that shows `Sales by Category` and repeat the action to set a verified answer:
#     * `Show me sales by category`
#     * `Which product categories have the most sales?`
#     * `Break down revenue by product category`
# 6. Select **Apply** and **Close**.
#
# You’ve created verified answers for two visuals with trigger phrases that describe common business questions.
# #### Add synonyms with linguistic modeling
# Synonyms help Copilot and Q&A interpret natural language variations for field and measure names. In this section, you add synonyms to key fields using the Q&A linguistic modeling setup.
# 1. On the **Modeling** ribbon, select **Q&A setup**.
# 2. In the Q&A setup dialog, select the **Synonyms** tab.
# 3. From the `Customer` table, locate `CustomerName`. Add the following synonyms, pressing **Enter** after each one:
#     * buyer
#     * client
# 4. From the `Product` table, locate `Category`. Add the following synonym:
#     * product category
#
# Notice the **Suggestions** and add `item`.
# > When you add the suggested synonym, you are prompted to share approved synonyms with your entire org. This choice helps provide consistency across your organization and support an enterprise ontology. Select OK to share the synonym.
#
# 5. From the `Sales` table, locate the `Profit Margin` measure. Add the following synonyms:
#     * margin
#     * profit percentage
#     * profitability
# 6. Locate the `Total Sales` measure. Add the following synonyms:
#     * income
#     * revenue
#     * total revenue
# 7. Close the Q&A setup dialog.
# ##### Publish and validate changes
# Publishing the report makes the semantic model available in the Power BI service, where you can test with Copilot and mark the model as approved.
# 1. **Save** the report and select **Publish** from the **Home** ribbon.
# 2. In the **Publish to Power BI** dialog, select the workspace you created earlier. Wait for publishing to complete.
# 3. When the success message appears, select the link to **Open** the report in the Power BI service, or navigate to your workspace in a browser.
# ##### Test with Copilot
# Validating your AI preparation confirms that Copilot uses the correct fields, measures, and verified answers. In this section, you test the published model with Copilot in the Power BI service, use HCAAT diagnostics to inspect Copilot’s reasoning, and mark the model as Approved for Copilot.
# 1. In the Power BI service, open the published report from your workspace.
# 2. On the report toolbar, select the **Copilot** button to open the Copilot pane.
# 3. In the Copilot pane, enter your question in **Ask a question about this report**. If the **Understand the data** option is available, select it before entering your question.
# 4. Ask a question that matches one of your verified answers:
#     * `What were total sales?`
#
# Copilot should return the predefined card visual showing total sales, rather than generating a new response.
# 5. Ask the second verified-answer question:
#     * `Show me sales by category`
#
# Copilot should return the bar chart visual you created the verified answer for.
# 6. Ask a question that tests your synonyms and AI instructions:
#     * `Show me the top products by profitability`
#
# Based on your AI instructions, Copilot should use the `Profit Margin` measure rather than the `Profit` measure. The synonym “profitability” should map correctly to `Profit Margin`.
# 7. Select the **How Copilot arrived at this answer** (HCAAT) link below the response. Review which fields, filters, and measures Copilot used. Confirm that Copilot selected the expected measure and didn’t use any hidden fields.
# 8. Ask an open-ended question that doesn’t have a verified answer:
#     * `Which city had the highest sales?`
#
# Select the HCAAT link again and verify that Copilot uses `City` and `Total Sales` without referencing any surrogate keys or ETL columns.
# 9. If any response is inaccurate, note the question. You can improve accuracy by adjusting AI instructions, adding a verified answer, or refining synonyms.
# ##### Mark the model as Approved for Copilot
# Approving a semantic model tells your organization that it’s been validated and is ready for AI consumption. In this task, you mark the published semantic model as Approved for Copilot.
# 1. Navigate back to your workspace.
# > Note: You might need to refresh the browser tab to see the semantic model.
#
# 2. Select the ellipsis (…) for the semantic model item and select **Settings**.
# 3. On the model details page, expand the **Approved for Copilot** section.
# 4. Check the **Approved for Copilot** option and select **Apply**.
#
# Your semantic model will have improved visibility in search results. It also removes the warning in standalone Copilot in Power BI that your organization hasn’t approved the data.
# #### Clean up resources
# In this exercise, you configured Prep for AI features in Power BI Desktop, added synonyms, published the model to a Fabric workspace, tested with Copilot and HCAAT diagnostics, and marked the model as Approved for Copilot.
# 1. Navigate to your workspace in the Power BI service.
# 2. In the workspace settings, select **Other** and then select **Remove this workspace**.

# %% [markdown]
# ### **Module assessment**

# %% [markdown]
# #### 1. A retail analytics team uses both gross margin amount and gross margin percentage to make pricing decisions. Copilot selects either measure when managers ask about margin. What should the team do first?
#
# A) Create a verified answer for every question that contains the word margin. \
# **B) Give each measure a distinct business name and a description that states its unit and calculation.** \
# C) Add an AI instruction that tells Copilot to choose whichever margin measure appears first.

# %% [markdown]
# #### 2. A semantic model exposes CustomerKey, LoadBatchID, Customer, and Sales for regional sales questions. Which change best prepares the gold layer for AI?
#
# A) Keep every field visible so Copilot has the maximum amount of context. \
# **B) Keep the business entities and trusted measures visible, and hide technical keys and load metadata.** \
# C) Replace the star schema with one flat table so Copilot doesn't need relationships.

# %% [markdown]
# #### 3. A pharmaceutical company has a board question that requires an approved measure, fixed regulatory filters, and a specific visual. Leaders phrase the question in several predictable ways. Which control best fits this requirement?
#
# **A) A verified answer with focused trigger phrases for the approved question.** \
# B) A synonym that maps the board's terminology to the measure. \
# C) A broad AI instruction that applies the regulatory filters to every question.

# %% [markdown]
# #### 4. An analytics team generates an ontology from an Import-mode semantic model. The definitions appear, but the team also expects generated data bindings that agents can query. What should the team evaluate?
#
# **A) Whether the semantic model should use Direct Lake mode with inbound public access for generated data bindings.** \
# B) Whether Foundry IQ can provide direct data bindings to the Import-mode semantic model. \
# C) Whether marking the semantic model as Approved for Copilot creates the missing bindings.

# %% [markdown]
# #### 5. During testing, a purchasing question returns the expected number, but diagnostics show that Copilot used a deprecated measure. What should the analytics team do before approving the semantic model?
#
# A) Approve the semantic model because the numeric result matches the expected answer. \
# **B) Hide or replace the deprecated measure, then rerun the same question and related regression tests.** \
# C) Create a verified answer so users can't see which measure produced the result.

# %% [markdown]
# ## **Understand Microsoft Fabric IQ fundamentals**

# %% [markdown]
# ### **Introduction**
