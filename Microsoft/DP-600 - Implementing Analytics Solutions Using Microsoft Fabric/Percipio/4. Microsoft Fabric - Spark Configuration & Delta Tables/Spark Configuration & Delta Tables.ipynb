# %% [markdown]
# # **[Microsoft Fabric: Spark Configuration & Delta Tables](https://accenture.percipio.com/courses/d5429f30-9e94-4e18-94d2-e7deeffee300)**

# %% [markdown]
# ## **1. Course Overview**
# ### Explanation
# This course focuses on advanced Spark administration and Delta Lake features in Microsoft Fabric. It covers Spark batch jobs, Spark pools, custom environments, Delta Table versioning, Time Travel, and the differences between Managed and External Delta Tables. It is highly relevant for the DP-600 exam because Spark and Delta Lake are major exam domains.
# ### Summary
# * Spark Batch Jobs
# * Spark History Server
# * Starter Pools & High Concurrency
# * Custom Spark Pools & Environments
# * Delta Table Versioning
# * Time Travel
# * Managed vs External Delta Tables

# %% [markdown]
# ## **2. Creating Python Scripts for Batch Jobs**
# ### Explanation
# The course begins by converting a Fabric Notebook into a Python script for batch execution.
# ### Key Concepts
# #### Interactive vs Batch Mode
# ##### Notebook
# * Interactive execution
# * Supports `display()`
# * Used for development and testing
# ##### Spark Job
# * Scheduled batch execution
# * Uses `.py` scripts
# * No interactive output
# #### Additional Batch Script Requirements
# * Create SparkSession manually
# * Configure logging
# * Use `__name__ == "__main__"` block
# * Remove display statements
# ### Summary
# Spark Jobs are production-ready batch workloads created from notebook code with additional Spark initialization logic.

# %% [markdown]
# ## **3. Creating and Monitoring Spark Batch Jobs**
# ### Explanation
# This section shows how to execute Python Spark scripts as Scheduled Spark Jobs.
# ### Configuration Steps
# * Upload `.py` file
# * Add Lakehouse Reference
# * Save Spark Job Definition
# * Execute manually or schedule execution
# ### Monitoring Features
# #### Run Details
# * Status
# * Duration
# * Application ID
# * Livy ID
# #### Resource Metrics
# * Executor utilization
# * Core allocation
# * Runtime information
# #### Logs
# * Driver stdout
# * Driver stderr
# * Prelaunch logs
# * Livy logs
# ### Summary
# Spark Jobs provide enterprise-scale execution, monitoring, logging, and troubleshooting capabilities.

# %% [markdown]
# ## **4. Spark History Server & Scheduling Spark Jobs**
# ### Explanation
# The Spark History Server provides diagnostics for completed and failed Spark jobs.
# ### Key Features
# #### Analyze Jobs
# * Completed jobs
# * Failed jobs
# * Resource usage
# * Performance bottlenecks
# #### Failure Investigation
# Example shown:
# * `Table already exists error`
# * `AnalysisException`
# * `Table creation failure`
# #### Job Scheduling
# Spark Jobs can be scheduled:
# * Minute
# * Hourly
# * Daily
# * Weekly
# #### Retry Policy
# Configure:
# * Maximum retries
# * Delay between retries
# * Unlimited retry options
# ### Summary
# The Spark History Server is the primary troubleshooting tool for Spark workload failures and performance analysis.

# %% [markdown]
# ## **5. Configuring Starter Pools & High Concurrency**
# ### Explanation
# This topic focuses on Spark execution performance.
# ### Starter Pool
# A preconfigured Spark environment that reduces startup time.
# #### Benefits
# * Faster notebook startup
# * Lower setup overhead
# * Ideal for learning and development
# ### Autoscale
# Automatically adjusts:
# * Number of nodes
# * Cluster size
#
# based on workload.
# ### Dynamic Executor Allocation
# Adjusts:
# * Number of executors
# * Resource consumption
#
# without changing node count.
# ### High Concurrency Sessions
# Allows multiple notebooks to share one Spark session.
# #### Benefits
# * Faster execution
# * Reduced startup times
# * Better resource utilization
# ### Summary
# Starter Pools and High Concurrency Sessions improve Spark efficiency and reduce notebook execution delays.

# %% [markdown]
# ## **6. Creating & Using Custom Spark Pools & Environments**
# ### Explanation
# Custom pools allow organizations to tune Spark resources.
# ### Custom Spark Pools
# #### Configurable Options
# * Node Family
#     * Memory Optimized
#     * Compute Optimized
#     * General Purpose
#     * Storage Optimized
# * Node Size
# * Autoscale
# * Executor Allocation
# ### Spark Environments
# Allow:
# * Custom runtimes
# * Custom libraries
# * Compute settings
# * Spark configuration properties
# #### Environment Features
# ##### Public Libraries
# Install from:
# * PyPI
# ##### Custom Libraries
# Upload:
# * JAR
# * WHL
# * TAR.GZ
# ##### Resource Files
# Store:
# * Config files
# * Static resources
# * Supporting files
# ### Summary
# Custom Pools and Environments provide workload-specific Spark optimization and dependency management.

# %% [markdown]
# ## **7. Viewing Versions & History of Delta Tables**
# ### Explanation
# Delta Tables keep a complete transaction history.
# ### Operations Performed
# * INSERT
# * UPDATE
# * DELETE
# ### DESCRIBE HISTORY Command
# ```sql
# DESCRIBE HISTORY employees
# ```
# Provides:
# * Version number
# * Timestamp
# * Operation type
# * User information
# * Audit history
# ### Delta Storage Structure
# #### Delta Log
# Contains:
# * Metadata
# * Transaction information
# * Versions
# #### Parquet Files
# Contain:
# * Actual data
# ### Summary
# Delta Tables automatically track every change and maintain a complete audit trail.

# %% [markdown]
# ## **8. Time Travelling with Delta Tables**
# ### Explanation
# Time Travel allows querying or restoring previous versions.
# #### Query by Timestamp
# ```sql
# SELECT * FROM employees
# TIMESTAMP AS OF '2024-09-15T11:59:18Z'
# ```
# #### Query by Version
# ```sql
# SELECT * FROM employees
# VERSION AS OF 2
# ```
# #### PySpark Version
# ```python
# .option("versionAsOf",2)
# ```
# #### Restore a Previous Version
# ```sql
# RESTORE employees
# TO VERSION AS OF 2
# ```
# #### Important Learning
# RESTORE does not overwrite history.
#
# Instead:
# * Creates a new version
# * Copies older state
# * Preserves audit history
# ### Summary
# Time Travel is one of Delta Lake's most powerful features and a favorite DP-600 exam topic.

# %% [markdown]
# ## **9. Managed & External Delta Tables**
# ### Explanation
# This is one of the most important DP-600 concepts.
# ### Managed Delta Table
# #### Characteristics
# * Data stored in Tables folder
# * Fabric manages metadata
# * Fabric manages data lifecycle
# * Dropping table removes:
#     * Metadata
#     * Data files
# ### External Delta Table
# #### Characteristics
# * Data stored outside Tables area
# * User controls storage location
# * Fabric manages only metadata
# * Dropping table removes:
#     * Metadata only
# * Data files remain intact
# ### Comparison Table
# | Feature | Managed Table | External Table |
# | --- | --- | --- |
# | Data Location | Tables folder | Custom location |
# | Metadata Managed | Yes | Yes |
# | Data Managed | Yes | No |
# | Drop Table Deletes Data | Yes | No |
# | Fabric Controls Storage | Yes | No |
# ### Summary
# Managed tables are simpler, while external tables provide flexibility and independent data lifecycle management.

# %% [markdown]
# ## **10. Creating Managed Delta Tables from Sparky**
# ### Explanation
# * Managed Delta Table creation:
# ```python
# df.write.format("delta") \
# .saveAsTable("phone_sales")
# ```
# ### Outcome
# * Table appears under Tables section.
# * Data stored within Fabric-managed location.
# * Delta metadata managed automatically.
# ### Summary
# Using `saveAsTable()` without specifying a path creates a managed Delta Table.

# %% [markdown]
# ## **11. Creating External Delta Tables from Spark**
# ### Explanation
# External table creation:
# ```python
# df.write.format("delta") \
# .saveAsTable(
# "phone_sales_external",
# path="Files/external")
# ```
# ### Outcome
# * Metadata registered as table
# * Data stored outside managed Tables area
# * Fabric tracks metadata only
# ### Another Scenario
# Saving only Delta files:
# ```python
# df.write.format("delta") \
# .save("Files/delta/phone_sales")
# ```
# Result:
# * Delta format files created
# * No table registration
# * Not queryable via SQL endpoint
# ### Summary
# External tables separate metadata management from data storage, while Delta files alone are simply storage artifacts.

# %% [markdown]
# ## **12. Course Summary**
# ### Key Topics Learned
# ✅ Spark Batch Jobs \
# ✅ Spark Job Monitoring \
# ✅ Spark History Server \
# ✅ Spark Scheduling & Retry Policies \
# ✅ Starter Pools \
# ✅ High Concurrency Sessions \
# ✅ Autoscaling \
# ✅ Dynamic Executor Allocation \
# ✅ Custom Spark Pools \
# ✅ Custom Environments \
# ✅ Delta Log Architecture \
# ✅ DESCRIBE HISTORY \
# ✅ Time Travel \
# ✅ RESTORE Operations \
# ✅ Managed Delta Tables \
# ✅ External Delta Tables \
# ✅ Delta File Storage Format
#
# ### DP-600 Exam Focus Areas (Must Revise)
# #### Highest Priority
# 1. Spark Jobs vs Notebooks
# 2. Spark History Server
# 3. High Concurrency Sessions
# 4. Autoscale & Dynamic Executors
# 5. DESCRIBE HISTORY
# 6. VERSION AS OF
# 7. TIMESTAMP AS OF
# 8. RESTORE TABLE
# 9. Managed vs External Tables
# 10. Delta Log Architecture
# #### Quick Memory Trick
# * Managed = Metadata + Data deleted together
# * External = Metadata deleted, Data survives
# * Time Travel = Query old versions
# * Restore = Creates new version from old version
# * DESCRIBE HISTORY = Audit trail of Delta Table

# %% [markdown]
# ## **Quiz**

# %% [markdown]
# ### In the Spark environment configuration, the properties related to the driver and executor define how the resources (CPU and memory) are allocated for running Spark applications. Which property should we increase in order to deal with a very large dataset?
#
# A) Spark executor core \
# B) Spark driver memory \
# **C) Spark executor memory** \
# D) Spark driver core

# %% [markdown]
# ### A delta table named employees currently has 5 versions. You now run the Spark SQL command "RESTORE employees TO VERSION AS OF 2". What is the latest version number after this command is executed successfully?
#
# A) 5 \
# **B) 6** \
# C) 2 \
# D) 3

# %% [markdown]
# ### You are preparing PySpark code for a script to be run in batch mode with a Spark Job. You download code from a Spark notebook and modify it suitably. What operation is not required in the Spark notebook, but absolutely essential in the batch script?
#
# A) retrieving the spark context \
# B) print statements with status updates \
# **C) initializing the Spark session** \
# D) setting the log level to DEBUG

# %% [markdown]
# ### You run a Spark job based on a PySpark script containing numerous Python print commands. In which section of the output details will these print statements be visible?
#
# A) Preview (stdout) logs \
# B) Driver (stderr) logs \
# C) Output data \
# **D) Driver (stdout) logs**

# %% [markdown]
# ### The line of code df.write.format("delta").saveAsTable("phone_sales") writes a managed Delta table named phone_sales. How is the table stored and accessed in the Lakehouse?
#
# **A) Both metadata and data are in the Tables section of the Lakehouse** \
# B) The URL of this table will point to the Files directory in the Lakehouse \
# **C) The URL of this table will point to the Tables directory in the Lakehouse** \
# D) The managed table only stores the metadata in the Lakehouse, while the data is stored outside in the Files directory

# %% [markdown]
# ### Managed and external delta tables differ in how the lifecycle of the data and table are coupled. Identify the accurate statement(s) below.
#
# A) When a managed table is dropped, only metadata is deleted \
# **B) When a managed table is dropped, both data and metadata are deleted** \
# C) When an external table is dropped, both data and metadata are deleted \
# **D) When an external table is dropped, only metadata is deleted**

# %% [markdown]
# ### You write out a dataframe to an external delta table, where the output location is in the File storage of the Lakehouse itself. When you invoke the SQL DROP command on this table, what happens?
#
# A) The parquet disappears from the Files section but the `_delta_log` does not \
# B) Both the parquet and the `_delta_log` disappear from the Files section \
# C) The `_delta_log` disappears from the Files section but the parquet does not \
# **D) The table disappears from the Tables section**

# %% [markdown]
# ### We create an empty delta table, and note that there are no parquet files to begin with. We then perform a series of operations, so that the number of versions is 5. How many parquet files will likely be found in the table directory (though the actual number of files may vary)?
#
# A) 1 \
# B) 0 \
# C) 20 \
# **D) 4**

# %% [markdown]
# ### You have two PySpark notebooks, A and B. You start with standard sessions and run the same query in each notebook - call these runs Qa and Qb. You then switch to a high concurrency session in notebook A and rerun the query, call this Qc. Then you switch to notebook B, use the available high concurrency session created in notebook A, and rerun the query, call this Qd. Which query will first benefit from the speedup of the high concurrency session?
#
# A) `Qc` \
# B) `Qb` \
# C) `Qa` \
# **D) `Qd`**

# %% [markdown]
# ### Fill in the blank: _______ is a web-based user interface in Apache Spark that allows users to view and diagnose the performance of completed and running Spark applications, providing detailed information about jobs, stages, tasks, and event timelines.
#
# **A) Spark History Server** \
# B) OneLake Log Server \
# C) Logs Status Page \
# D) Jobs Status Page
